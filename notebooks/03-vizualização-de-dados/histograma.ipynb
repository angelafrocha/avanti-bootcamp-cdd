# %% [markdown]
# # **Prática de aula (Entendimento de dados) - 02: Histograma**

# %% [markdown]
# Essa prática tem o objetivo de exercitar o conhecimento aprendido na aula de "Entendimento de dados".
#
# Ferramentas:
#
# * **pandas** : biblioteca de manipulação de dados tabulares
# * **matplotlib** : biblioteca de visualização de dados (médio nível)
# * **seaborn** : biblioteca de visualização de dados (alto nível)

# %%
import pandas as ps
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = sns.load_dataset('penguins')
df.head(5)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ### Visualização #02

# %%
#Add linhas
sns.set_style('whitegrid')

# descriçao das labels
ax= sns.histplot(data= df, x= 'body_mass_g')
plt.ylabel('Quantidade')
plt.xlabel('Massa(g)')
plt.title('Distribuião da massa dos pinguins')

# add linha de origem e removendo as bordas
ax.set(frame_on=False)
ax.axhline(0, color='k', clip_on=False)
plt.show()
